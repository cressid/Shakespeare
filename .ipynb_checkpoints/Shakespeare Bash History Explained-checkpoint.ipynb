# %% [markdown]
# # Testing Bash

# %%
# %%bash
# echo "hello from $BASH"
# Out:
# hello from /bin/bash

# %%
# %%bash
# ls -lh
# Out:
# total 157824
# -rw-r--r--  1 elena  staff   667K Feb 18 15:14 AllsWellThatEndsWell.js
# -rw-r--r--  1 elena  staff   819K Feb 18 15:14 AntonyAndCleopatra.js
# -rw-r--r--  1 elena  staff   587K Feb 18 15:14 AsYouLikeIt.js
# -rw-r--r--  1 elena  staff   9.7K Feb 18 15:14 CharTimelines.js
# -rw-r--r--  1 elena  staff    11K Feb 18 15:14 CharacterTable.js
# -rw-r--r--  1 elena  staff   438K Feb 18 15:14 ComedyOfErrors.js
# -rw-r--r--  1 elena  staff   809K Feb 18 15:14 Coriolanus.js
# -rw-r--r--  1 elena  staff   800K Feb 18 15:14 Cymbeline.js
# -rw-r--r--  1 elena  staff   3.8K Feb 18 15:14 ForceDirrected.html
# -rw-r--r--  1 elena  staff   654K Feb 18 15:14 HenryIV.js
# -rw-r--r--  1 elena  staff   692K Feb 18 15:14 HenryV.js
# -rw-r--r--  1 elena  staff   706K Feb 18 15:14 HenryVIII.js
# -rw-r--r--  1 elena  staff   624K Feb 18 15:14 HenryVIPart1.js
# -rw-r--r--  1 elena  staff   700K Feb 18 15:14 HenryVIPart2.js
# -rw-r--r--  1 elena  staff   668K Feb 18 15:14 HenryVIPart3.js
# ...

# %%
# %%bash
# less ComedyOfErrors.js
# Out:
# var ComedyOfErrors = [
#   {
#     "line_number": "",
#     "speech_number": 132,
#     "play_name": "A Comedy of Errors",
#     "text_entry": "ACT I",
#     "line_id": 22428,
#     "speaker": "Stage Directions"
#   },
#   {
#     "line_number": "",
#     "speech_number": 132,
#     "play_name": "A Comedy of Errors",
#     "text_entry": "SCENE I. A hall in DUKE SOLINUS'S palace.",
#     "line_id": 22429,
#     "speaker": "Stage Directions"
#   },
#   {
#     "line_number": "",
#     "speech_number": 132,
#     "play_name": "A Comedy of Errors",
#     "text_entry": "Enter DUKE SOLINUS, AEGEON, Gaoler, Officers, and other Attendants",
#     "line_id": 22430,
#     "speaker": "Stage Directions"
#   },
#   {
#     "line_number": "1.1.1",
#     "speech_number": 1,
#     "play_name": "A Comedy of Errors",
#     "text_entry": "Proceed, Solinus, to procure my fall",
#     "line_id": 22431,
#     "speaker": "AEGEON"
#   },
#   {
#     "line_number": "1.1.2",
#     "speech_number": 1,
# ...

# %%
# %%bash
# sort ComedyOfErrors.js
# Out:
#     "line_id": 22428,
#     "line_id": 22429,
#     "line_id": 22430,
#     "line_id": 22431,
#     "line_id": 22432,
#     "line_id": 22433,
#     "line_id": 22434,
#     "line_id": 22435,
#     "line_id": 22436,
#     "line_id": 22437,
#     "line_id": 22438,
#     "line_id": 22439,
#     "line_id": 22440,
#     "line_id": 22441,
#     "line_id": 22442,
#     "line_id": 22443,
#     "line_id": 22444,
#     "line_id": 22445,
#     "line_id": 22446,
#     "line_id": 22447,
#     "line_id": 22448,
#     "line_id": 22449,
#     "line_id": 22450,
#     "line_id": 22451,
#     "line_id": 22452,
#     "line_id": 22453,
#     "line_id": 22454,
#     "line_id": 22455,
#     "line_id": 22456,
#     "line_id": 22457,
#     "line_id": 22458,
#     "line_id": 22459,
#     "line_id": 22460,
#     "line_id": 22461,
#     "line_id": 22462,
#     "line_id": 22463,
#     "line_id": 22464,
#     "line_id": 22465,
#     "line_id": 22466,
#     "line_id": 22467,
#     "line_id": 22468,
# ...

# %%
# %%bash
# grep -C 3 "OF SYRACUSE" ComedyOfErrors.js
# Out:
#     "play_name": "A Comedy of Errors",
#     "text_entry": "Go bear it to the Centaur, where we host,",
#     "line_id": 22601,
#     "speaker": "OF SYRACUSE"
#   },
#   {
#     "line_number": "1.2.11",
# --
# --
#     "play_name": "A Comedy of Errors",
#     "text_entry": "And stay there, Dromio, till I come to thee.",
#     "line_id": 22602,
#     "speaker": "OF SYRACUSE"
#   },
#   {
#     "line_number": "1.2.12",
# --
# --
#     "play_name": "A Comedy of Errors",
#     "text_entry": "Within this hour it will be dinner-time:",
#     "line_id": 22603,
#     "speaker": "OF SYRACUSE"
#   },
#   {
#     "line_number": "1.2.13",
# --
# --
#     "play_name": "A Comedy of Errors",
#     "text_entry": "Till that, I'll view the manners of the town,",
#     "line_id": 22604,
#     "speaker": "OF SYRACUSE"
#   },
#   {
#     "line_number": "1.2.14",
# --
# --
#     "play_name": "A Comedy of Errors",
#     "text_entry": "Peruse the traders, gaze upon the buildings,",
#     "line_id": 22605,
# ...
